# %% [markdown]
# # ***Predicting The Salary Of A Person Using Their Years Of Experience Using Linear Regression ✨***

# %% [markdown]
# #Importing CSV File

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d1e18422-7542-43da-a078-1f50f284f76c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1e18422-7542-43da-a078-1f50f284f76c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Uploaded CSV File

# %%
import pandas as pd

df = pd.read_csv('Salary_Data.csv')
print(df)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# #Performing Linear Regression on CSV File

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
def ss(exp_train,sala_train):
  reg = LinearRegression().fit(exp_train,sala_train)
  return reg


df = pd.read_csv('Salary_Data.csv')
ex = df['YearsExperience']
sal = df['Salary']

ex = np.reshape(np.array(ex),(len(ex),1))
sal = np.reshape(np.array(sal),(len(sal),1))

ex_train,ex_test,sal_train,sal_test = train_test_split(ex,sal)

reg1 = ss(ex_train,sal_train)

print(reg1.coef_)
print(reg1.intercept_)
print(reg1.predict([[6]])) #here Years of Experience =6

print(reg1.score(ex_train,sal_train))
print(reg1.score(ex_test,sal_test))
# Out:
# [[9246.9824614]]
# [26689.38067756]
# [[82171.27544596]]

# %% [markdown]
# #Testing the accuracy

# %%
exp = df['YearsExperience']

exp = np.reshape(np.array(exp),(len(exp),1))
print(exp)
y_true = df['Salary']
y_pred = reg1.predict(exp)
print(y_true)
print(y_pred)
r2_score(y_pred,y_true)

# %% [markdown]
# #Ploting A Graph for linear Regression

# %%
plt.figure(figsize = (12,10))
sns.regplot(x = ex_train,y=sal_train,scatter = True, color="r",marker = "*")
plt.xlabel("Experience_Train")
plt.ylabel("Salary_train")
plt.title("Regression Plot")
# Out:
# Text(0.5, 1.0, 'Regression Plot')

# %% [markdown]
# #Ploting Graph for Train and Test Data

# %%
plt.figure(figsize = (12,10))
plt.scatter(x=ex_train,y=sal_train,color='cyan',label="Train_Data")
plt.scatter(x=ex_test,y=sal_test,color='r',label="Test_Data")
plt.plot(ex_test,reg1.predict(ex_test)) #Ploting A Line Based on test data and predict data of experience
plt.xlabel("Years of Experiece")
plt.ylabel("Salary")
plt.legend()
plt.show()
